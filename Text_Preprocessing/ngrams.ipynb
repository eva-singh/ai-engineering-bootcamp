# %%
import pandas as pd
import nltk
import matplotlib as plt

# %%
tokens=['the', 'football', 'winnipeg', 'love', 'heart', 'principle', 'quitioent', 'true', 'nat']
unigrams=(pd.Series(nltk.ngrams(tokens,1)).value_counts())
print(unigrams)
# Out:
# (the,)          1
# (football,)     1
# (winnipeg,)     1
# (love,)         1
# (heart,)        1
# (principle,)    1
# (quitioent,)    1
# (true,)         1
# (nat,)          1
# Name: count, dtype: int64

# %%
unigrams[:10].sort_values().plot.barh(color="lightsalmon", width=9, figsize=(12, 8))
# Out:
# <Axes: >
